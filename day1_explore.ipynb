# %%
import pandas as pd
df = pd.read_csv("data/A_message_delivery.csv")
print(df.shape)
df.head()
df.info()
df.describe(include="all")
# Out:
# (30300, 12)
# ,<class 'pandas.DataFrame'>
# ,RangeIndex: 30300 entries, 0 to 30299
# ,Data columns (total 12 columns):
# , #   Column            Non-Null Count  Dtype
# ,---  ------            --------------  -----
# , 0   message_id        30300 non-null  str
# , 1   campaign_id       30300 non-null  str
# , 2   account_id        30300 non-null  str
# , 3   sender_name       30300 non-null  str
# , 4   recipient_id      30048 non-null  str
# , 5   network_provider  29714 non-null  str
# , 6   sent_at           30300 non-null  str
# , 7   delivered_at      27705 non-null  str
# , 8   delivery_status   30300 non-null  str
# , 9   error_code        2595 non-null   str
# , 10  message_parts     30300 non-null  int64
# , 11  cost              30300 non-null  float64
# ,dtypes: float64(1), int64(1), str(10)
# ,memory usage: 2.8 MB
#          message_id campaign_id account_id sender_name recipient_id  \
# count         30300       30300      30300       30300        30048
# unique        30000          50        200           7          100
# top     MSG00014959      CMP020    ACC0190   Sender_04     9XXXXX99
# freq              3         663        182        4406          373
# mean            NaN         NaN        NaN         NaN          NaN
# std             NaN         NaN        NaN         NaN          NaN
# min             NaN         NaN        NaN         NaN          NaN
# 25%             NaN         NaN        NaN         NaN          NaN
# 50%             NaN         NaN        NaN         NaN          NaN
# 75%             NaN         NaN        NaN         NaN          NaN
# max             NaN         NaN        NaN         NaN          NaN
#
#        network_provider              sent_at         delivered_at  \
# count             29714                30300                27705
# unique                4                29893                27348
# top          Provider_A  2026-04-13 09:22:15  2026-04-19 05:30:03
# freq              12023                    3                    3
# mean                NaN                  NaN                  NaN
# std                 NaN                  NaN                  NaN
# min                 NaN                  NaN                  NaN
# 25%                 NaN                  NaN                  NaN
# 50%                 NaN                  NaN                  NaN
# 75%                 NaN                  NaN                  NaN
# max                 NaN                  NaN                  NaN
#
#        delivery_status error_code  message_parts          cost
# count            30300       2595   30300.000000  30300.000000
# unique               4          6            NaN           NaN
# top          delivered       E203            NaN           NaN
# freq             27705        483            NaN           NaN
# mean               NaN        NaN       1.964587     50.746383
# std                NaN        NaN       6.318214    170.124913
# min                NaN        NaN       1.000000    -70.290000
# 25%                NaN        NaN       1.000000     23.540000
# 50%                NaN        NaN       1.000000     27.120000
# 75%                NaN        NaN       2.000000     44.500000
# max                NaN        NaN      90.000000   4141.500000

# %%
df["delivery_status"].value_counts(dropna=False)
print((df["delivery_status"] != "delivered").mean() * 100, "% failed")
# Out:
# 8.564356435643566 % failed
